# %% [markdown]
# # 正则化

# %%
import sys, numpy as np
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Using TensorFlow backend.
# D:\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# D:\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\Anaconda\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
images, labels = (x_train[0:1000].reshape(1000, 28*28) / 255, y_train[0:1000])
one_hot_labels = np.zeros((len(labels), 10))
for i, l in enumerate(labels):
#     print(i, l)
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28*28) / 255
test_labels = np.zeros((len(y_test), 10))
for i, l in enumerate(y_test):
    test_labels[i][l] = 1
    pass
np.random.seed(1)
relu = lambda x: (x>=0) * x
relu2deriv = lambda x: x>=0
alpha, iterations, hidden_size, pixels_per_image, num_labels = (0.005, 350, 40, 784, 10)

weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

for j in range(iterations):
    error, correct_cnt = (0.0, 0)
    for i in range(len(images)):
        layer_0 = images[i: i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        error += np.sum((labels[i: i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == np.argmax(labels[i: i+1]))
        
        layer_2_delta = labels[i: i+1] - layer_2
        layer_1_delta = np.dot(layer_2_delta, weights_1_2.T) * relu2deriv(layer_1)
        
        weights_1_2 += alpha * np.dot(layer_1.T, layer_2_delta)
        weights_0_1 += alpha * np.dot(layer_0.T, layer_1_delta)
        pass
    print('\r' + 'I: ' + str(j) + 'error:' + str(error / float(len(images)))[0:5] + 'correct:' + str(correct_cnt / float(len(images))))
# Out:
# I: 0error:0.722correct:0.537
# I: 1error:0.512correct:0.753
# I: 2error:0.448correct:0.804
# I: 3error:0.411correct:0.837
# I: 4error:0.385correct:0.846
# I: 5error:0.367correct:0.863
# I: 6error:0.352correct:0.876
# I: 7error:0.340correct:0.884
# I: 8error:0.329correct:0.892
# I: 9error:0.320correct:0.897
# I: 10error:0.312correct:0.901
# I: 11error:0.304correct:0.904
# I: 12error:0.297correct:0.91
# I: 13error:0.291correct:0.914
# I: 14error:0.286correct:0.918
# I: 15error:0.281correct:0.918
# I: 16error:0.276correct:0.921
# I: 17error:0.272correct:0.922
# I: 18error:0.268correct:0.926
# I: 19error:0.264correct:0.927
# I: 20error:0.260correct:0.93
# I: 21error:0.257correct:0.932
# I: 22error:0.254correct:0.933
# I: 23error:0.250correct:0.935
# I: 24error:0.247correct:0.935
# I: 25error:0.245correct:0.939
# I: 26error:0.242correct:0.941
# I: 27error:0.239correct:0.941
# I: 28error:0.237correct:0.941
# I: 29error:0.235correct:0.945
# I: 30error:0.232correct:0.946
# I: 31error:0.230correct:0.947
# I: 32error:0.228correct:0.947
# I: 33error:0.227correct:0.948
# I: 34error:0.225correct:0.949
# I: 35error:0.223correct:0.953
# I: 36error:0.221correct:0.953
# I: 37error:0.220correct:0.955
# I: 38error:0.218correct:0.956
# I: 39error:0.217correct:0.956
# I: 40error:0.215correct:0.956
# I: 41error:0.214correct:0.958
# I: 42error:0.213correct:0.958
# I: 43error:0.212correct:0.96
# I: 44error:0.210correct:0.961
# I: 45error:0.209correct:0.963
# I: 46error:0.208correct:0.963
# I: 47error:0.207correct:0.963
# I: 48error:0.206correct:0.965
# I: 49error:0.205correct:0.966
# I: 50error:0.204correct:0.966
# I: 51error:0.203correct:0.966
# I: 52error:0.202correct:0.966
# I: 53error:0.201correct:0.967
# I: 54error:0.200correct:0.967
# I: 55error:0.199correct:0.967
# I: 56error:0.198correct:0.967
# I: 57error:0.197correct:0.967
# I: 58error:0.196correct:0.967
# I: 59error:0.195correct:0.967
# I: 60error:0.194correct:0.967
# I: 61error:0.193correct:0.968
# I: 62error:0.193correct:0.97
# I: 63error:0.192correct:0.97
# I: 64error:0.191correct:0.971
# I: 65error:0.190correct:0.972
# I: 66error:0.189correct:0.972
# I: 67error:0.189correct:0.974
# I: 68error:0.188correct:0.974
# I: 69error:0.187correct:0.974
# I: 70error:0.186correct:0.975
# I: 71error:0.186correct:0.975
# I: 72error:0.185correct:0.976
# I: 73error:0.184correct:0.976
# I: 74error:0.183correct:0.976
# I: 75error:0.183correct:0.977
# I: 76error:0.182correct:0.978
# I: 77error:0.181correct:0.978
# I: 78error:0.180correct:0.978
# I: 79error:0.180correct:0.979
# I: 80error:0.179correct:0.979
# I: 81error:0.178correct:0.979
# I: 82error:0.178correct:0.979
# I: 83error:0.177correct:0.98
# I: 84error:0.176correct:0.98
# I: 85error:0.176correct:0.98
# I: 86error:0.175correct:0.98
# I: 87error:0.174correct:0.98
# I: 88error:0.174correct:0.98
# I: 89error:0.173correct:0.98
# I: 90error:0.172correct:0.981
# I: 91error:0.172correct:0.981
# I: 92error:0.171correct:0.981
# I: 93error:0.170correct:0.981
# I: 94error:0.170correct:0.983
# I: 95error:0.169correct:0.983
# I: 96error:0.169correct:0.983
# I: 97error:0.168correct:0.983
# I: 98error:0.167correct:0.983
# I: 99error:0.167correct:0.983
# I: 100error:0.166correct:0.984
# I: 101error:0.166correct:0.984
# I: 102error:0.165correct:0.984
# I: 103error:0.165correct:0.984
# I: 104error:0.164correct:0.984
# I: 105error:0.164correct:0.984
# I: 106error:0.163correct:0.984
# I: 107error:0.163correct:0.984
# I: 108error:0.162correct:0.984
# I: 109error:0.162correct:0.984
# I: 110error:0.161correct:0.984
# I: 111error:0.161correct:0.984
# I: 112error:0.161correct:0.985
# I: 113error:0.160correct:0.985
# I: 114error:0.160correct:0.986
# I: 115error:0.159correct:0.986
# I: 116error:0.159correct:0.986
# I: 117error:0.158correct:0.986
# I: 118error:0.158correct:0.986
# I: 119error:0.158correct:0.986
# I: 120error:0.157correct:0.986
# I: 121error:0.157correct:0.986
# I: 122error:0.156correct:0.986
# I: 123error:0.156correct:0.986
# I: 124error:0.155correct:0.986
# I: 125error:0.155correct:0.987
# I: 126error:0.155correct:0.986
# I: 127error:0.154correct:0.987
# I: 128error:0.154correct:0.988
# I: 129error:0.153correct:0.989
# I: 130error:0.153correct:0.99
# I: 131error:0.153correct:0.991
# I: 132error:0.152correct:0.991
# I: 133error:0.152correct:0.991
# I: 134error:0.151correct:0.991
# I: 135error:0.151correct:0.991
# I: 136error:0.151correct:0.991
# I: 137error:0.150correct:0.991
# I: 138error:0.150correct:0.991
# I: 139error:0.149correct:0.991
# I: 140error:0.149correct:0.991
# I: 141error:0.148correct:0.991
# I: 142error:0.148correct:0.991
# I: 143error:0.148correct:0.991
# I: 144error:0.147correct:0.991
# I: 145error:0.147correct:0.991
# I: 146error:0.147correct:0.991
# I: 147error:0.146correct:0.991
# I: 148error:0.146correct:0.991
# I: 149error:0.145correct:0.991
# I: 150error:0.145correct:0.991
# I: 151error:0.145correct:0.991
# I: 152error:0.144correct:0.991
# I: 153error:0.144correct:0.991
# I: 154error:0.143correct:0.991
# I: 155error:0.143correct:0.991
# I: 156error:0.143correct:0.991
# I: 157error:0.142correct:0.991
# I: 158error:0.142correct:0.991
# I: 159error:0.142correct:0.992
# I: 160error:0.141correct:0.992
# I: 161error:0.141correct:0.992
# I: 162error:0.141correct:0.992
# I: 163error:0.140correct:0.992
# I: 164error:0.140correct:0.992
# I: 165error:0.140correct:0.992
# I: 166error:0.139correct:0.992
# I: 167error:0.139correct:0.992
# I: 168error:0.139correct:0.992
# I: 169error:0.138correct:0.992
# I: 170error:0.138correct:0.992
# I: 171error:0.138correct:0.992
# I: 172error:0.137correct:0.992
# I: 173error:0.137correct:0.992
# I: 174error:0.137correct:0.992
# I: 175error:0.137correct:0.992
# I: 176error:0.136correct:0.992
# I: 177error:0.136correct:0.993
# I: 178error:0.136correct:0.993
# I: 179error:0.135correct:0.994
# I: 180error:0.135correct:0.995
# I: 181error:0.135correct:0.995
# I: 182error:0.135correct:0.995
# I: 183error:0.134correct:0.995
# I: 184error:0.134correct:0.995
# I: 185error:0.134correct:0.995
# I: 186error:0.133correct:0.996
# I: 187error:0.133correct:0.996
# I: 188error:0.133correct:0.995
# I: 189error:0.133correct:0.995
# I: 190error:0.132correct:0.995
# I: 191error:0.132correct:0.996
# I: 192error:0.132correct:0.996
# I: 193error:0.132correct:0.996
# I: 194error:0.131correct:0.996
# I: 195error:0.131correct:0.996
# I: 196error:0.131correct:0.996
# I: 197error:0.130correct:0.996
# I: 198error:0.130correct:0.996
# I: 199error:0.130correct:0.998
# I: 200error:0.130correct:0.998
# I: 201error:0.129correct:0.998
# I: 202error:0.129correct:0.998
# I: 203error:0.129correct:0.998
# I: 204error:0.129correct:0.998
# I: 205error:0.128correct:0.998
# I: 206error:0.128correct:0.998
# I: 207error:0.128correct:0.998
# I: 208error:0.128correct:0.998
# I: 209error:0.127correct:0.998
# I: 210error:0.127correct:0.998
# I: 211error:0.127correct:0.998
# I: 212error:0.127correct:0.998
# I: 213error:0.127correct:0.998
# I: 214error:0.126correct:0.998
# I: 215error:0.126correct:0.998
# I: 216error:0.126correct:0.998
# I: 217error:0.126correct:0.998
# I: 218error:0.125correct:0.998
# I: 219error:0.125correct:0.998
# I: 220error:0.125correct:0.998
# I: 221error:0.125correct:0.998
# I: 222error:0.125correct:0.998
# I: 223error:0.124correct:0.998
# I: 224error:0.124correct:0.998
# I: 225error:0.124correct:0.998
# I: 226error:0.124correct:0.998
# I: 227error:0.124correct:0.998
# I: 228error:0.124correct:0.998
# I: 229error:0.123correct:0.998
# I: 230error:0.123correct:0.998
# I: 231error:0.123correct:0.998
# I: 232error:0.123correct:0.998
# I: 233error:0.123correct:0.998
# I: 234error:0.122correct:0.998
# I: 235error:0.122correct:0.998
# I: 236error:0.122correct:0.998
# I: 237error:0.122correct:0.998
# I: 238error:0.122correct:0.998
# I: 239error:0.122correct:0.998
# I: 240error:0.121correct:0.998
# I: 241error:0.121correct:0.998
# I: 242error:0.121correct:0.998
# I: 243error:0.121correct:0.998
# I: 244error:0.121correct:0.998
# I: 245error:0.121correct:0.998
# I: 246error:0.120correct:0.998
# I: 247error:0.120correct:0.998
# I: 248error:0.120correct:0.999
# I: 249error:0.120correct:0.999
# I: 250error:0.120correct:0.999
# I: 251error:0.120correct:0.999
# I: 252error:0.120correct:0.999
# I: 253error:0.119correct:0.999
# I: 254error:0.119correct:0.999
# I: 255error:0.119correct:0.999
# I: 256error:0.119correct:0.999
# I: 257error:0.119correct:0.999
# I: 258error:0.119correct:0.999
# I: 259error:0.118correct:0.999
# I: 260error:0.118correct:0.999
# I: 261error:0.118correct:0.999
# I: 262error:0.118correct:0.999
# I: 263error:0.118correct:0.999
# I: 264error:0.118correct:0.999
# I: 265error:0.118correct:0.999
# I: 266error:0.117correct:0.999
# I: 267error:0.117correct:0.999
# I: 268error:0.117correct:0.999
# I: 269error:0.117correct:0.999
# I: 270error:0.117correct:0.999
# I: 271error:0.117correct:0.999
# I: 272error:0.117correct:0.999
# I: 273error:0.116correct:0.999
# I: 274error:0.116correct:0.999
# I: 275error:0.116correct:0.999
# I: 276error:0.116correct:0.999
# I: 277error:0.116correct:0.999
# I: 278error:0.116correct:0.999
# I: 279error:0.116correct:0.999
# I: 280error:0.115correct:0.999
# I: 281error:0.115correct:0.999
# I: 282error:0.115correct:0.999
# I: 283error:0.115correct:0.999
# I: 284error:0.115correct:0.999
# I: 285error:0.115correct:0.999
# I: 286error:0.115correct:0.999
# I: 287error:0.114correct:0.999
# I: 288error:0.114correct:0.999
# I: 289error:0.114correct:0.999
# I: 290error:0.114correct:0.999
# I: 291error:0.114correct:0.999
# I: 292error:0.114correct:0.999
# I: 293error:0.114correct:0.999
# I: 294error:0.114correct:0.999
# I: 295error:0.113correct:0.999
# I: 296error:0.113correct:0.999
# I: 297error:0.113correct:0.999
# I: 298error:0.113correct:0.999
# I: 299error:0.113correct:0.999
# I: 300error:0.113correct:0.999
# I: 301error:0.113correct:0.999
# I: 302error:0.113correct:0.999
# I: 303error:0.112correct:0.999
# I: 304error:0.112correct:0.999
# I: 305error:0.112correct:0.999
# I: 306error:0.112correct:0.999
# I: 307error:0.112correct:0.999
# I: 308error:0.112correct:0.999
# I: 309error:0.112correct:0.999
# I: 310error:0.112correct:0.999
# I: 311error:0.112correct:0.999
# I: 312error:0.111correct:0.999
# I: 313error:0.111correct:0.999
# I: 314error:0.111correct:0.999
# I: 315error:0.111correct:0.999
# I: 316error:0.111correct:0.999
# I: 317error:0.111correct:0.999
# I: 318error:0.111correct:0.999
# I: 319error:0.111correct:0.999
# I: 320error:0.111correct:0.999
# I: 321error:0.110correct:0.999
# I: 322error:0.110correct:0.999
# I: 323error:0.110correct:0.999
# I: 324error:0.110correct:0.999
# I: 325error:0.110correct:0.999
# I: 326error:0.110correct:0.999
# I: 327error:0.110correct:0.999
# I: 328error:0.110correct:0.999
# I: 329error:0.110correct:0.999
# I: 330error:0.110correct:0.999
# I: 331error:0.110correct:0.999
# I: 332error:0.109correct:0.999
# I: 333error:0.109correct:1.0
# I: 334error:0.109correct:1.0
# I: 335error:0.109correct:1.0
# I: 336error:0.109correct:1.0
# I: 337error:0.109correct:1.0
# I: 338error:0.109correct:1.0
# I: 339error:0.109correct:1.0
# I: 340error:0.109correct:1.0
# I: 341error:0.109correct:1.0
# I: 342error:0.109correct:1.0
# I: 343error:0.109correct:1.0
# I: 344error:0.109correct:1.0
# I: 345error:0.109correct:1.0
# I: 346error:0.108correct:1.0
# I: 347error:0.108correct:1.0
# I: 348error:0.108correct:1.0
# I: 349error:0.108correct:1.0

# %% [markdown]
# ## 过拟合

# %%
if (j % 10 == 0) or (j == iterations - 1):
    error, correct_cnt = (0.0, 0)
    
    for i in range(len(test_images)):
        layer_0 = test_images[i: i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        pass
    print('test-error: ' , error / float(len(test_images)), ' correct_cnt: ', correct_cnt/float(len(test_images)))
# Out:
# test-error:  6534.055358949952  correct_cnt:  0.7073

# %% [markdown]
# ## 行业标准正则化 ： dropout
# * 在训练过程中随机关闭神经元

# %%
images, labels = (x_train[0:1000].reshape(1000, 28*28) / 255, y_train[0:1000])
one_hot_labels = np.zeros((len(labels), 10))
for i, l in enumerate(labels):
#     print(i, l)
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28*28) / 255
test_labels = np.zeros((len(y_test), 10))
for i, l in enumerate(y_test):
    test_labels[i][l] = 1
    pass
np.random.seed(1)
relu = lambda x: (x>=0) * x
relu2deriv = lambda x: x>=0
alpha, iterations, hidden_size, pixels_per_image, num_labels = (0.005, 350, 40, 784, 10)

weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

for j in range(iterations):
    error, correct_cnt = (0.0, 0)
    for i in range(len(images)):
        layer_0 = images[i: i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        # 关闭节点，防止过拟合
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        # * 为对应位置相乘
        layer_1 *= dropout_mask * 2
        
        layer_2 = np.dot(layer_1, weights_1_2)
        error += np.sum((labels[i: i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == np.argmax(labels[i: i+1]))
        
        layer_2_delta = labels[i: i+1] - layer_2
        layer_1_delta = np.dot(layer_2_delta, weights_1_2.T) * relu2deriv(layer_1)
        # 还原节点失效现场
        layer_1_delta *= dropout_mask
        
        weights_1_2 += alpha * np.dot(layer_1.T, layer_2_delta)
        weights_0_1 += alpha * np.dot(layer_0.T, layer_1_delta)
        pass
    print('\r' + 'I: ' + str(j) + 'error:' + str(error / float(len(images)))[0:5] + 'correct:' + str(correct_cnt / float(len(images))))
# Out:
# I: 0error:0.885correct:0.289
# I: 1error:0.716correct:0.5
# I: 2error:0.669correct:0.559
# I: 3error:0.628correct:0.589
# I: 4error:0.621correct:0.588
# I: 5error:0.607correct:0.612
# I: 6error:0.576correct:0.63
# I: 7error:0.582correct:0.625
# I: 8error:0.575correct:0.639
# I: 9error:0.566correct:0.64
# I: 10error:0.564correct:0.647
# I: 11error:0.569correct:0.638
# I: 12error:0.549correct:0.65
# I: 13error:0.556correct:0.654
# I: 14error:0.536correct:0.669
# I: 15error:0.544correct:0.673
# I: 16error:0.535correct:0.683
# I: 17error:0.542correct:0.671
# I: 18error:0.533correct:0.675
# I: 19error:0.527correct:0.676
# I: 20error:0.530correct:0.681
# I: 21error:0.528correct:0.686
# I: 22error:0.520correct:0.685
# I: 23error:0.522correct:0.693
# I: 24error:0.516correct:0.699
# I: 25error:0.513correct:0.698
# I: 26error:0.527correct:0.686
# I: 27error:0.506correct:0.701
# I: 28error:0.500correct:0.713
# I: 29error:0.505correct:0.703
# I: 30error:0.508correct:0.71
# I: 31error:0.508correct:0.727
# I: 32error:0.494correct:0.718
# I: 33error:0.496correct:0.705
# I: 34error:0.480correct:0.716
# I: 35error:0.471correct:0.747
# I: 36error:0.507correct:0.714
# I: 37error:0.479correct:0.73
# I: 38error:0.487correct:0.717
# I: 39error:0.483correct:0.733
# I: 40error:0.492correct:0.719
# I: 41error:0.471correct:0.743
# I: 42error:0.466correct:0.752
# I: 43error:0.477correct:0.728
# I: 44error:0.475correct:0.727
# I: 45error:0.467correct:0.725
# I: 46error:0.469correct:0.73
# I: 47error:0.472correct:0.738
# I: 48error:0.462correct:0.746
# I: 49error:0.448correct:0.766
# I: 50error:0.462correct:0.742
# I: 51error:0.460correct:0.743
# I: 52error:0.470correct:0.753
# I: 53error:0.472correct:0.739
# I: 54error:0.464correct:0.736
# I: 55error:0.466correct:0.748
# I: 56error:0.446correct:0.746
# I: 57error:0.462correct:0.729
# I: 58error:0.445correct:0.754
# I: 59error:0.473correct:0.739
# I: 60error:0.472correct:0.746
# I: 61error:0.454correct:0.749
# I: 62error:0.470correct:0.732
# I: 63error:0.448correct:0.756
# I: 64error:0.458correct:0.759
# I: 65error:0.447correct:0.763
# I: 66error:0.453correct:0.76
# I: 67error:0.448correct:0.766
# I: 68error:0.465correct:0.751
# I: 69error:0.445correct:0.764
# I: 70error:0.463correct:0.744
# I: 71error:0.456correct:0.746
# I: 72error:0.452correct:0.758
# I: 73error:0.445correct:0.774
# I: 74error:0.451correct:0.765
# I: 75error:0.467correct:0.746
# I: 76error:0.457correct:0.754
# I: 77error:0.453correct:0.762
# I: 78error:0.447correct:0.777
# I: 79error:0.460correct:0.758
# I: 80error:0.461correct:0.764
# I: 81error:0.465correct:0.741
# I: 82error:0.464correct:0.761
# I: 83error:0.446correct:0.758
# I: 84error:0.457correct:0.771
# I: 85error:0.449correct:0.767
# I: 86error:0.471correct:0.739
# I: 87error:0.450correct:0.762
# I: 88error:0.450correct:0.766
# I: 89error:0.459correct:0.762
# I: 90error:0.462correct:0.749
# I: 91error:0.441correct:0.772
# I: 92error:0.449correct:0.781
# I: 93error:0.426correct:0.765
# I: 94error:0.439correct:0.769
# I: 95error:0.449correct:0.773
# I: 96error:0.461correct:0.748
# I: 97error:0.461correct:0.748
# I: 98error:0.445correct:0.799
# I: 99error:0.455correct:0.773
# I: 100error:0.452correct:0.769
# I: 101error:0.458correct:0.769
# I: 102error:0.453correct:0.769
# I: 103error:0.440correct:0.779
# I: 104error:0.449correct:0.773
# I: 105error:0.441correct:0.781
# I: 106error:0.460correct:0.768
# I: 107error:0.439correct:0.792
# I: 108error:0.458correct:0.758
# I: 109error:0.440correct:0.793
# I: 110error:0.439correct:0.778
# I: 111error:0.469correct:0.755
# I: 112error:0.430correct:0.777
# I: 113error:0.448correct:0.776
# I: 114error:0.456correct:0.782
# I: 115error:0.455correct:0.776
# I: 116error:0.445correct:0.78
# I: 117error:0.463correct:0.765
# I: 118error:0.465correct:0.747
# I: 119error:0.442correct:0.776
# I: 120error:0.451correct:0.778
# I: 121error:0.449correct:0.783
# I: 122error:0.442correct:0.78
# I: 123error:0.425correct:0.789
# I: 124error:0.427correct:0.786
# I: 125error:0.451correct:0.776
# I: 126error:0.451correct:0.773
# I: 127error:0.448correct:0.775
# I: 128error:0.453correct:0.761
# I: 129error:0.443correct:0.766
# I: 130error:0.452correct:0.783
# I: 131error:0.453correct:0.775
# I: 132error:0.464correct:0.758
# I: 133error:0.433correct:0.801
# I: 134error:0.450correct:0.777
# I: 135error:0.451correct:0.78
# I: 136error:0.458correct:0.781
# I: 137error:0.449correct:0.789
# I: 138error:0.439correct:0.78
# I: 139error:0.428correct:0.79
# I: 140error:0.445correct:0.779
# I: 141error:0.420correct:0.792
# I: 142error:0.461correct:0.78
# I: 143error:0.446correct:0.778
# I: 144error:0.452correct:0.783
# I: 145error:0.449correct:0.784
# I: 146error:0.455correct:0.768
# I: 147error:0.463correct:0.767
# I: 148error:0.441correct:0.798
# I: 149error:0.432correct:0.779
# I: 150error:0.457correct:0.783
# I: 151error:0.441correct:0.784
# I: 152error:0.466correct:0.769
# I: 153error:0.443correct:0.782
# I: 154error:0.453correct:0.79
# I: 155error:0.453correct:0.761
# I: 156error:0.450correct:0.774
# I: 157error:0.461correct:0.767
# I: 158error:0.446correct:0.776
# I: 159error:0.433correct:0.792
# I: 160error:0.456correct:0.774
# I: 161error:0.439correct:0.784
# I: 162error:0.465correct:0.763
# I: 163error:0.447correct:0.772
# I: 164error:0.433correct:0.802
# I: 165error:0.466correct:0.781
# I: 166error:0.455correct:0.787
# I: 167error:0.437correct:0.789
# I: 168error:0.448correct:0.777
# I: 169error:0.438correct:0.782
# I: 170error:0.439correct:0.801
# I: 171error:0.455correct:0.769
# I: 172error:0.451correct:0.771
# I: 173error:0.451correct:0.79
# I: 174error:0.434correct:0.784
# I: 175error:0.456correct:0.781
# I: 176error:0.457correct:0.78
# I: 177error:0.447correct:0.769
# I: 178error:0.450correct:0.775
# I: 179error:0.449correct:0.774
# I: 180error:0.453correct:0.782
# I: 181error:0.434correct:0.787
# I: 182error:0.433correct:0.809
# I: 183error:0.440correct:0.776
# I: 184error:0.433correct:0.801
# I: 185error:0.452correct:0.776
# I: 186error:0.441correct:0.788
# I: 187error:0.437correct:0.783
# I: 188error:0.435correct:0.789
# I: 189error:0.441correct:0.772
# I: 190error:0.433correct:0.784
# I: 191error:0.422correct:0.792
# I: 192error:0.453correct:0.785
# I: 193error:0.457correct:0.77
# I: 194error:0.438correct:0.788
# I: 195error:0.427correct:0.796
# I: 196error:0.443correct:0.768
# I: 197error:0.427correct:0.796
# I: 198error:0.432correct:0.774
# I: 199error:0.458correct:0.77
# I: 200error:0.442correct:0.796
# I: 201error:0.438correct:0.784
# I: 202error:0.435correct:0.794
# I: 203error:0.436correct:0.787
# I: 204error:0.430correct:0.788
# I: 205error:0.444correct:0.788
# I: 206error:0.439correct:0.785
# I: 207error:0.456correct:0.771
# I: 208error:0.436correct:0.779
# I: 209error:0.441correct:0.794
# I: 210error:0.441correct:0.79
# I: 211error:0.432correct:0.793
# I: 212error:0.425correct:0.782
# I: 213error:0.443correct:0.78
# I: 214error:0.432correct:0.773
# I: 215error:0.424correct:0.799
# I: 216error:0.427correct:0.792
# I: 217error:0.431correct:0.787
# I: 218error:0.431correct:0.786
# I: 219error:0.435correct:0.781
# I: 220error:0.434correct:0.777
# I: 221error:0.439correct:0.758
# I: 222error:0.433correct:0.795
# I: 223error:0.433correct:0.788
# I: 224error:0.454correct:0.788
# I: 225error:0.431correct:0.79
# I: 226error:0.428correct:0.784
# I: 227error:0.432correct:0.797
# I: 228error:0.428correct:0.815
# I: 229error:0.437correct:0.79
# I: 230error:0.431correct:0.803
# I: 231error:0.436correct:0.773
# I: 232error:0.429correct:0.791
# I: 233error:0.426correct:0.795
# I: 234error:0.426correct:0.782
# I: 235error:0.431correct:0.796
# I: 236error:0.438correct:0.782
# I: 237error:0.421correct:0.793
# I: 238error:0.410correct:0.796
# I: 239error:0.423correct:0.799
# I: 240error:0.430correct:0.788
# I: 241error:0.425correct:0.798
# I: 242error:0.436correct:0.784
# I: 243error:0.402correct:0.794
# I: 244error:0.443correct:0.782
# I: 245error:0.424correct:0.78
# I: 246error:0.422correct:0.796
# I: 247error:0.419correct:0.799
# I: 248error:0.431correct:0.802
# I: 249error:0.426correct:0.795
# I: 250error:0.433correct:0.789
# I: 251error:0.417correct:0.793
# I: 252error:0.409correct:0.808
# I: 253error:0.403correct:0.807
# I: 254error:0.406correct:0.813
# I: 255error:0.413correct:0.794
# I: 256error:0.426correct:0.787
# I: 257error:0.428correct:0.799
# I: 258error:0.408correct:0.808
# I: 259error:0.429correct:0.797
# I: 260error:0.422correct:0.79
# I: 261error:0.431correct:0.785
# I: 262error:0.437correct:0.79
# I: 263error:0.435correct:0.784
# I: 264error:0.424correct:0.797
# I: 265error:0.422correct:0.797
# I: 266error:0.419correct:0.794
# I: 267error:0.443correct:0.788
# I: 268error:0.407correct:0.8
# I: 269error:0.422correct:0.793
# I: 270error:0.430correct:0.803
# I: 271error:0.411correct:0.804
# I: 272error:0.432correct:0.796
# I: 273error:0.413correct:0.802
# I: 274error:0.405correct:0.818
# I: 275error:0.407correct:0.807
# I: 276error:0.423correct:0.796
# I: 277error:0.411correct:0.807
# I: 278error:0.412correct:0.8
# I: 279error:0.415correct:0.817
# I: 280error:0.425correct:0.79
# I: 281error:0.430correct:0.796
# I: 282error:0.437correct:0.787
# I: 283error:0.411correct:0.815
# I: 284error:0.402correct:0.811
# I: 285error:0.421correct:0.792
# I: 286error:0.419correct:0.81
# I: 287error:0.418correct:0.775
# I: 288error:0.419correct:0.803
# I: 289error:0.408correct:0.812
# I: 290error:0.428correct:0.792
# I: 291error:0.424correct:0.801
# I: 292error:0.421correct:0.803
# I: 293error:0.420correct:0.804
# I: 294error:0.425correct:0.789
# I: 295error:0.411correct:0.808
# I: 296error:0.428correct:0.788
# I: 297error:0.403correct:0.808
# I: 298error:0.410correct:0.811
# I: 299error:0.407correct:0.815
# I: 300error:0.407correct:0.804
# I: 301error:0.416correct:0.809
# I: 302error:0.402correct:0.828
# I: 303error:0.408correct:0.81
# I: 304error:0.424correct:0.81
# I: 305error:0.417correct:0.804
# I: 306error:0.416correct:0.787
# I: 307error:0.405correct:0.816
# I: 308error:0.394correct:0.827
# I: 309error:0.403correct:0.812
# I: 310error:0.415correct:0.793
# I: 311error:0.415correct:0.795
# I: 312error:0.413correct:0.806
# I: 313error:0.406correct:0.816
# I: 314error:0.410correct:0.811
# I: 315error:0.410correct:0.812
# I: 316error:0.414correct:0.796
# I: 317error:0.410correct:0.806
# I: 318error:0.407correct:0.823
# I: 319error:0.432correct:0.784
# I: 320error:0.415correct:0.812
# I: 321error:0.408correct:0.809
# I: 322error:0.398correct:0.814
# I: 323error:0.407correct:0.815
# I: 324error:0.404correct:0.808
# I: 325error:0.404correct:0.819
# I: 326error:0.399correct:0.811
# I: 327error:0.386correct:0.832
# I: 328error:0.409correct:0.816
# I: 329error:0.404correct:0.829
# I: 330error:0.418correct:0.817
# I: 331error:0.416correct:0.803
# I: 332error:0.419correct:0.801
# I: 333error:0.419correct:0.806
# I: 334error:0.415correct:0.811
# I: 335error:0.378correct:0.826
# I: 336error:0.405correct:0.819
# I: 337error:0.395correct:0.822
# I: 338error:0.408correct:0.814
# I: 339error:0.411correct:0.818
# I: 340error:0.408correct:0.814
# I: 341error:0.414correct:0.809
# I: 342error:0.397correct:0.832
# I: 343error:0.412correct:0.805
# I: 344error:0.399correct:0.821
# I: 345error:0.408correct:0.806
# I: 346error:0.389correct:0.826
# I: 347error:0.422correct:0.795
# I: 348error:0.408correct:0.814
# I: 349error:0.418correct:0.802

# %%
if (j % 10 == 0) or (j == iterations - 1):
    error, correct_cnt = (0.0, 0)
    
    for i in range(len(test_images)):
        layer_0 = test_images[i: i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        pass
    print('test-error: ' , float(len(test_images)), ' correct_cnt: ', correct_cnt/float(len(test_images)))
# Out:
# test-error:  4212.303091754279  correct_cnt:  0.8078

# %% [markdown]
# ## 批量梯度下降
# * 提高训练度和收敛速度的方法

# %%
images, labels = (x_train[0:1000].reshape(1000, 28*28) / 255, y_train[0:1000])
one_hot_labels = np.zeros((len(labels), 10))
for i, l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28*28) / 255
test_labels = np.zeros((len(y_test), 10))
for i, l in enumerate(y_test):
    test_labels[i][l] = 1
    pass
np.random.seed(1)
relu = lambda x: (x>=0) * x
relu2deriv = lambda x: x>=0
# 100个为一批次
batch_size = 100
# 修改权重矩阵的维度为100
alpha, iterations, hidden_size, pixels_per_image, num_labels = (0.001, 300, 100, 784, 10)

weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

for j in range(iterations):
    error, correct_cnt = (0.0, 0)
    
    # 批量训练
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end = (i * batch_size, (i+1) * batch_size)
        layer_0 = images[batch_start: batch_end]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        # 关闭节点，防止过拟合
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        # * 为对应位置相乘并放大信号
        layer_1 *= dropout_mask * 2
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((labels[batch_start: batch_end] - layer_2) ** 2)
        # 批量修改
        for k in range(batch_size):
            correct_cnt += int(np.argmax(layer_2[k: k+1]) == np.argmax(labels[batch_start+k: batch_start+k+1])) 
            pass
        layer_2_delta = labels[batch_start: batch_end] - layer_2 / batch_size

        layer_1_delta = np.dot(layer_2_delta, weights_1_2.T) * relu2deriv(layer_1)

        # 还原节点失效现场
        layer_1_delta *= dropout_mask

        weights_1_2 += alpha * np.dot(layer_1.T, layer_2_delta)
        weights_0_1 += alpha * np.dot(layer_0.T, layer_1_delta)
        pass    
    print('\r' + 'I: ' + str(j) + 'error:' + str(error / float(len(images)))[0:5] + 'correct:' + str(correct_cnt / float(len(images))))
# Out:
# I: 0error:6.174correct:0.134
# I: 1error:185.1correct:0.169
# I: 2error:730.7correct:0.219
# I: 3error:890.3correct:0.298
# I: 4error:900.9correct:0.415
# I: 5error:958.6correct:0.495
# I: 6error:1091.correct:0.52
# I: 7error:1236.correct:0.564
# I: 8error:1444.correct:0.586
# I: 9error:1663.correct:0.597
# I: 10error:1914.correct:0.607
# I: 11error:2062.correct:0.641
# I: 12error:2329.correct:0.658
# I: 13error:2379.correct:0.68
# I: 14error:2553.correct:0.683
# I: 15error:2729.correct:0.701
# I: 16error:2890.correct:0.723
# I: 17error:3045.correct:0.722
# I: 18error:3104.correct:0.752
# I: 19error:3160.correct:0.745
# I: 20error:3249.correct:0.751
# I: 21error:3431.correct:0.754
# I: 22error:3429.correct:0.779
# I: 23error:3449.correct:0.775
# I: 24error:3580.correct:0.782
# I: 25error:3802.correct:0.798
# I: 26error:3888.correct:0.792
# I: 27error:3900.correct:0.802
# I: 28error:3928.correct:0.809
# I: 29error:3993.correct:0.807
# I: 30error:3940.correct:0.817
# I: 31error:4148.correct:0.805
# I: 32error:4077.correct:0.804
# I: 33error:4201.correct:0.823
# I: 34error:4195.correct:0.807
# I: 35error:4313.correct:0.823
# I: 36error:4359.correct:0.813
# I: 37error:4411.correct:0.828
# I: 38error:4373.correct:0.822
# I: 39error:4643.correct:0.82
# I: 40error:4630.correct:0.827
# I: 41error:4699.correct:0.822
# I: 42error:4826.correct:0.837
# I: 43error:4656.correct:0.823
# I: 44error:4722.correct:0.837
# I: 45error:4816.correct:0.841
# I: 46error:4682.correct:0.831
# I: 47error:4812.correct:0.848
# I: 48error:5087.correct:0.838
# I: 49error:5073.correct:0.83
# I: 50error:4658.correct:0.836
# I: 51error:5048.correct:0.83
# I: 52error:5147.correct:0.845
# I: 53error:4945.correct:0.83
# I: 54error:5059.correct:0.825
# I: 55error:5187.correct:0.851
# I: 56error:5530.correct:0.843
# I: 57error:5320.correct:0.841
# I: 58error:5241.correct:0.852
# I: 59error:5352.correct:0.827
# I: 60error:5433.correct:0.835
# I: 61error:5412.correct:0.846
# I: 62error:5260.correct:0.848
# I: 63error:5469.correct:0.851
# I: 64error:5335.correct:0.84
# I: 65error:5385.correct:0.845
# I: 66error:5290.correct:0.839
# I: 67error:5703.correct:0.845
# I: 68error:5629.correct:0.833
# I: 69error:5476.correct:0.833
# I: 70error:5634.correct:0.836
# I: 71error:5657.correct:0.841
# I: 72error:5671.correct:0.854
# I: 73error:5566.correct:0.85
# I: 74error:5460.correct:0.845
# I: 75error:5588.correct:0.843
# I: 76error:5594.correct:0.852
# I: 77error:5633.correct:0.843
# I: 78error:5855.correct:0.848
# I: 79error:5480.correct:0.84
# I: 80error:5789.correct:0.85
# I: 81error:5996.correct:0.867
# I: 82error:5828.correct:0.85
# I: 83error:5804.correct:0.845
# I: 84error:5951.correct:0.843
# I: 85error:5799.correct:0.839
# I: 86error:5931.correct:0.846
# I: 87error:5880.correct:0.846
# I: 88error:5946.correct:0.858
# I: 89error:5973.correct:0.849
# I: 90error:5781.correct:0.846
# I: 91error:5975.correct:0.843
# I: 92error:5877.correct:0.853
# I: 93error:6041.correct:0.84
# I: 94error:5866.correct:0.853
# I: 95error:6019.correct:0.848
# I: 96error:5956.correct:0.858
# I: 97error:6063.correct:0.855
# I: 98error:6340.correct:0.871
# I: 99error:6109.correct:0.871
# I: 100error:6072.correct:0.864
# I: 101error:6129.correct:0.863
# I: 102error:6146.correct:0.839
# I: 103error:6090.correct:0.847
# I: 104error:6024.correct:0.856
# I: 105error:6296.correct:0.856
# I: 106error:5994.correct:0.858
# I: 107error:6520.correct:0.863
# I: 108error:6247.correct:0.865
# I: 109error:6468.correct:0.849
# I: 110error:6303.correct:0.862
# I: 111error:6323.correct:0.86
# I: 112error:6187.correct:0.86
# I: 113error:6094.correct:0.878
# I: 114error:6209.correct:0.883
# I: 115error:6356.correct:0.861
# I: 116error:6192.correct:0.858
# I: 117error:6353.correct:0.864
# I: 118error:6246.correct:0.861
# I: 119error:6349.correct:0.872
# I: 120error:6511.correct:0.849
# I: 121error:6307.correct:0.873
# I: 122error:5955.correct:0.866
# I: 123error:6223.correct:0.874
# I: 124error:6428.correct:0.877
# I: 125error:6263.correct:0.868
# I: 126error:6052.correct:0.854
# I: 127error:6309.correct:0.862
# I: 128error:6079.correct:0.863
# I: 129error:6292.correct:0.872
# I: 130error:6260.correct:0.856
# I: 131error:6557.correct:0.86
# I: 132error:6360.correct:0.88
# I: 133error:6490.correct:0.866
# I: 134error:6299.correct:0.873
# I: 135error:6397.correct:0.866
# I: 136error:6357.correct:0.872
# I: 137error:6187.correct:0.865
# I: 138error:6336.correct:0.872
# I: 139error:6443.correct:0.864
# I: 140error:6205.correct:0.87
# I: 141error:6221.correct:0.857
# I: 142error:6257.correct:0.871
# I: 143error:6236.correct:0.867
# I: 144error:6349.correct:0.866
# I: 145error:6315.correct:0.884
# I: 146error:6705.correct:0.877
# I: 147error:6524.correct:0.887
# I: 148error:6444.correct:0.86
# I: 149error:6413.correct:0.87
# I: 150error:6455.correct:0.872
# I: 151error:6076.correct:0.856
# I: 152error:6292.correct:0.873
# I: 153error:6347.correct:0.879
# I: 154error:6735.correct:0.885
# I: 155error:6613.correct:0.873
# I: 156error:6720.correct:0.872
# I: 157error:6124.correct:0.876
# I: 158error:6302.correct:0.858
# I: 159error:6313.correct:0.874
# I: 160error:6223.correct:0.872
# I: 161error:6554.correct:0.871
# I: 162error:6230.correct:0.875
# I: 163error:6298.correct:0.871
# I: 164error:6509.correct:0.87
# I: 165error:6476.correct:0.871
# I: 166error:6510.correct:0.892
# I: 167error:6507.correct:0.874
# I: 168error:6598.correct:0.867
# I: 169error:6546.correct:0.869
# I: 170error:6107.correct:0.88
# I: 171error:6573.correct:0.877
# I: 172error:6505.correct:0.886
# I: 173error:6678.correct:0.888
# I: 174error:6671.correct:0.874
# I: 175error:6439.correct:0.87
# I: 176error:6255.correct:0.868
# I: 177error:6598.correct:0.884
# I: 178error:6397.correct:0.882
# I: 179error:6543.correct:0.898
# I: 180error:6214.correct:0.879
# I: 181error:6668.correct:0.879
# I: 182error:6351.correct:0.879
# I: 183error:6607.correct:0.893
# I: 184error:6458.correct:0.881
# I: 185error:6365.correct:0.89
# I: 186error:6505.correct:0.871
# I: 187error:6442.correct:0.873
# I: 188error:6231.correct:0.874
# I: 189error:6187.correct:0.872
# I: 190error:6259.correct:0.879
# I: 191error:6530.correct:0.881
# I: 192error:6388.correct:0.867
# I: 193error:6587.correct:0.878
# I: 194error:6681.correct:0.89
# I: 195error:6579.correct:0.878
# I: 196error:6441.correct:0.876
# I: 197error:6111.correct:0.872
# I: 198error:6468.correct:0.89
# I: 199error:6712.correct:0.875
# I: 200error:6676.correct:0.872
# I: 201error:6436.correct:0.879
# I: 202error:6487.correct:0.876
# I: 203error:6779.correct:0.876
# I: 204error:6380.correct:0.873
# I: 205error:6614.correct:0.882
# I: 206error:6196.correct:0.878
# I: 207error:6568.correct:0.887
# I: 208error:6578.correct:0.889
# I: 209error:6431.correct:0.894
# I: 210error:6751.correct:0.881
# I: 211error:6330.correct:0.893
# I: 212error:6526.correct:0.877
# I: 213error:6656.correct:0.881
# I: 214error:6398.correct:0.882
# I: 215error:6806.correct:0.878
# I: 216error:6814.correct:0.889
# I: 217error:6458.correct:0.877
# I: 218error:6548.correct:0.886
# I: 219error:6503.correct:0.892
# I: 220error:6588.correct:0.886
# I: 221error:6652.correct:0.887
# I: 222error:6711.correct:0.889
# I: 223error:6871.correct:0.881
# I: 224error:6598.correct:0.893
# I: 225error:6645.correct:0.884
# I: 226error:6765.correct:0.887
# I: 227error:6482.correct:0.89
# I: 228error:6422.correct:0.871
# I: 229error:6449.correct:0.875
# I: 230error:6663.correct:0.881
# I: 231error:6451.correct:0.873
# I: 232error:6987.correct:0.898
# I: 233error:6670.correct:0.885
# I: 234error:6767.correct:0.884
# I: 235error:6410.correct:0.881
# I: 236error:6666.correct:0.884
# I: 237error:6695.correct:0.884
# I: 238error:6439.correct:0.885
# I: 239error:6644.correct:0.891
# I: 240error:6601.correct:0.881
# I: 241error:6781.correct:0.891
# I: 242error:6421.correct:0.884
# I: 243error:6573.correct:0.881
# I: 244error:6290.correct:0.876
# I: 245error:6508.correct:0.89
# I: 246error:6872.correct:0.91
# I: 247error:6811.correct:0.898
# I: 248error:6629.correct:0.886
# I: 249error:6708.correct:0.899
# I: 250error:6708.correct:0.894
# I: 251error:6803.correct:0.894
# I: 252error:6651.correct:0.889
# I: 253error:6925.correct:0.899
# I: 254error:6410.correct:0.876
# I: 255error:6763.correct:0.901
# I: 256error:6687.correct:0.89
# I: 257error:6620.correct:0.906
# I: 258error:6672.correct:0.892
# I: 259error:6533.correct:0.886
# I: 260error:6706.correct:0.892
# I: 261error:6529.correct:0.892
# I: 262error:6637.correct:0.885
# I: 263error:6578.correct:0.888
# I: 264error:6638.correct:0.898
# I: 265error:6833.correct:0.902
# I: 266error:6745.correct:0.897
# I: 267error:6807.correct:0.915
# I: 268error:6649.correct:0.892
# I: 269error:6839.correct:0.89
# I: 270error:6687.correct:0.898
# I: 271error:6786.correct:0.908
# I: 272error:6673.correct:0.882
# I: 273error:6526.correct:0.897
# I: 274error:6588.correct:0.884
# I: 275error:6502.correct:0.897
# I: 276error:6751.correct:0.904
# I: 277error:6627.correct:0.899
# I: 278error:6743.correct:0.884
# I: 279error:6665.correct:0.893
# I: 280error:6677.correct:0.895
# I: 281error:6471.correct:0.89
# I: 282error:6685.correct:0.9
# I: 283error:6733.correct:0.903
# I: 284error:6579.correct:0.894
# I: 285error:6907.correct:0.898
# I: 286error:6602.correct:0.901
# I: 287error:6785.correct:0.881
# I: 288error:6757.correct:0.887
# I: 289error:6803.correct:0.894
# I: 290error:6574.correct:0.906
# I: 291error:6984.correct:0.903
# I: 292error:6473.correct:0.907
# I: 293error:6687.correct:0.902
# I: 294error:6844.correct:0.899
# I: 295error:6824.correct:0.897
# I: 296error:6723.correct:0.906
# I: 297error:6536.correct:0.899
# I: 298error:6614.correct:0.888
# I: 299error:6688.correct:0.9

# %%
if (j % 10 == 0) or (j == iterations - 1):
    error, correct_cnt = (0.0, 0)
    
    for i in range(len(test_images)):
        layer_0 = test_images[i: i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        pass
    print('test-error: ' , error / float(len(test_images)), ' correct_cnt: ', correct_cnt / float(len(test_images)))
# Out:
# test-error:  5605.257247671009  correct_cnt:  0.8141
